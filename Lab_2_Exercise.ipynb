# %% [markdown]
# <a href="https://colab.research.google.com/github/ejini6969/Optimization-Deep-Learning-ODL-/blob/main/Lab_2_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise

# %% [markdown]
# Using the boston_pre data, perform the data preprocessing

# %%
#Mounting our Drive to Google Colab
from google.colab import drive
drive.mount("/drive")
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

path = "/drive/MyDrive/boston_pre.csv"
boston = pd.read_csv(path)

# %%
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  PRICE  PRICE2
# 0     15.3  396.90   4.98   24.0     NaN
# 1     17.8  396.90   9.14   21.6     NaN
# 2     17.8  392.83   4.03   34.7     NaN
# 3     18.7  394.63   2.94   33.4     NaN
# 4     18.7  396.90   5.33   36.2     NaN

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     503 non-null    float64
#  1   ZN       505 non-null    float64
#  2   INDUS    492 non-null    float64
#  3   CHAS     504 non-null    float64
#  4   NOX      501 non-null    float64
#  5   RM       500 non-null    float64
#  6   AGE      498 non-null    float64
#  7   DIS      502 non-null    float64
#  8   RAD      497 non-null    float64
#  9   TAX      500 non-null    float64
#  10  PTRATIO  502 non-null    float64
#  11  B        501 non-null    float64
#  12  LSTAT    504 non-null    float64
#  13  PRICE    505 non-null    float64
#  14  PRICE2   0 non-null      float64
# dtypes: float64(15)
# memory usage: 59.4 KB

# %%
# drop rows if all contain null value
bost1 = boston.dropna(how = 'all')
bost1
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  PRICE  PRICE2
# 0       15.3  396.90   4.98   24.0     NaN
# ...

# %%
# drop all columns if only contain NULL / NAN value (Price2)
bost1 = bost1.dropna(axis = 1, how = 'all')
bost1
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  PRICE
# 0       15.3  396.90   4.98   24.0
# ...

# %%
bost1 = bost1.drop(["CHAS"], axis = 1) # drop CHAS column since all contain 0
bost1
# Out:
#         CRIM    ZN  INDUS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO  \
# 0    0.00632  18.0   2.31  0.538  6.575  65.2  4.0900  1.0  296.0     15.3
# 1    0.02731   0.0   7.07  0.469  6.421  78.9  4.9671  2.0  242.0     17.8
# 2    0.02729   0.0   7.07  0.469  7.185  61.1  4.9671  2.0  242.0     17.8
# 3    0.03237   0.0   2.18  0.458  6.998  45.8  6.0622  3.0  222.0     18.7
# 4    0.06905   0.0   2.18  0.458  7.147  54.2  6.0622  3.0  222.0     18.7
# ..       ...   ...    ...    ...    ...   ...     ...  ...    ...      ...
# 501  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786  1.0  273.0     21.0
# 502  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875  1.0  273.0     21.0
# 503  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675  1.0  273.0     21.0
# 504  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889  1.0  273.0     21.0
# 505  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050  1.0  273.0     21.0
#
#           B  LSTAT  PRICE
# 0    396.90   4.98   24.0
# ...

# %%
bost1.isnull().sum()
# Out:
# CRIM        2
# ZN          0
# INDUS      13
# NOX         4
# RM          5
# AGE         7
# DIS         3
# RAD         8
# TAX         5
# PTRATIO     3
# B           4
# LSTAT       1
# PRICE       0
# dtype: int64

# %%
# importing the class called SimpleImputer from impute model in sklearn
from sklearn.impute import SimpleImputer

# to replace the missing value we create below object for SimpleImputer class
imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
imputer.fit(bost1.iloc[:,:-1])

# replacing the missing value using transform method
bost1.iloc[:,:-1] = imputer.transform(bost1.iloc[:,:-1]) # do not include last column since all are valid value

# %%
bost1.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# PRICE      0
# dtype: int64

# %%
# convert age column from float to int type
bost1 = bost1.astype({'AGE':'int'})
bost1
# Out:
#         CRIM    ZN  INDUS    NOX     RM  AGE     DIS  RAD    TAX  PTRATIO  \
# 0    0.00632  18.0   2.31  0.538  6.575   65  4.0900  1.0  296.0     15.3
# 1    0.02731   0.0   7.07  0.469  6.421   78  4.9671  2.0  242.0     17.8
# 2    0.02729   0.0   7.07  0.469  7.185   61  4.9671  2.0  242.0     17.8
# 3    0.03237   0.0   2.18  0.458  6.998   45  6.0622  3.0  222.0     18.7
# 4    0.06905   0.0   2.18  0.458  7.147   54  6.0622  3.0  222.0     18.7
# ..       ...   ...    ...    ...    ...  ...     ...  ...    ...      ...
# 501  0.06263   0.0  11.93  0.573  6.593   69  2.4786  1.0  273.0     21.0
# 502  0.04527   0.0  11.93  0.573  6.120   76  2.2875  1.0  273.0     21.0
# 503  0.06076   0.0  11.93  0.573  6.976   91  2.1675  1.0  273.0     21.0
# 504  0.10959   0.0  11.93  0.573  6.794   89  2.3889  1.0  273.0     21.0
# 505  0.04741   0.0  11.93  0.573  6.030   80  2.5050  1.0  273.0     21.0
#
#           B  LSTAT  PRICE
# 0    396.90   4.98   24.0
# ...

# %%
Y = bost1["PRICE"]
X = bost1.drop(["PRICE"], axis = 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 1)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (404, 12)
# (101, 12)
# (404,)
# (101,)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print('Standardized X_train:', X_train)
print('')
print('Standardized X_test:', X_test)
# Out:
# Standardized X_train: [[ 0.70442675 -0.50181234  1.05291808 ...  0.80146137  0.32560153
#    0.87404428]
#  [-0.38905295 -0.50181234 -0.58590266 ... -0.25119798  0.41035067
#   -0.72989635]
#  [-0.39530575  0.54535804 -0.84659085 ...  0.57262238  0.43710201
#   -0.47967599]
#  ...
#  [ 0.44859265 -0.50181234  1.05291808 ...  0.80146137  0.39544008
#    1.02445765]
#  [-0.34877769 -0.50181234 -0.68988503 ... -0.48003697  0.34445903
#   -0.43469255]
#  [-0.38730355 -0.50181234 -0.725034   ...  0.34378339  0.39905809
#   -0.35175434]]
#
# Standardized X_test: [[-0.35185503 -0.50181234 -0.14800507 ... -0.02235899  0.43710201
#   -1.13755874]
#  [-0.40342168  1.80196248 -1.04430381 ... -0.38850137  0.33919647
#   -1.12771861]
#  [-0.37851529 -0.50181234 -0.58590266 ... -0.25119798  0.43710201
#    2.5553002 ]
#  ...
#  [-0.34806968 -0.50181234 -0.68988503 ... -0.48003697  0.27374339
#   -1.12490715]
#  [-0.3955778  -0.50181234 -0.13189513 ...  0.00891263  0.42273961
#   -0.34753714]
# ...
